# %%
import pandas as pd
filename = "optimization_results.csv"
df = pd.read_csv(filename)
cols = ['symbol','sharpe','sortino','atr_multiplier',]
df_stats = df[cols]
print(df_stats)

print(df_stats.describe())
# Out:
#   symbol    sharpe    sortino  atr_multiplier
# 0    BTC  6.317091  12.773356             1.1
# 1    ETH  7.332898  14.956104             1.0
# 2    XRP  6.104195  11.791532             1.1
# 3    BNB  3.603990   1.603394             1.1
# 4    SOL  8.433071  16.454466             1.0
# 5    TRX  4.055300   6.517357             1.2
# 6   DOGE  7.773966  14.820003             1.0
# 7    ADA  7.365477  16.751493             1.0
# 8   LINK  7.956147  14.700096             1.0
# 9    BCH  6.340451  10.973523             1.2
#           sharpe    sortino  atr_multiplier
# count  10.000000  10.000000       10.000000
# mean    6.528259  12.134132        1.070000
# std     1.615684   4.784982        0.082327
# min     3.603990   1.603394        1.000000
# 25%     6.157419  11.178025        1.000000
# 50%     6.836675  13.736726        1.050000
# 75%     7.671844  14.922079        1.100000
# max     8.433071  16.751493        1.200000
